# %% [markdown]
# # 【seaborn】グラフの作成方法と主な使い方【まとめ】

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib
sns.set(font="IPAexGothic")
# %matplotlib inline

# %% [markdown]
# ## スタイルの設定
# set_style()
# <table>
# <thead>
# <tr>
# <th align="left">スタイル名</th>
# <th align="left">背景</th>
# <th align="left">グリッド線</th>
# </tr>
# </thead>
# <tbody><tr>
# <td align="left">darkgrid（デフォルト）</td>
# <td align="left">暗</td>
# <td align="left">あり</td>
# </tr>
# <tr>
# <td align="left">whitegrid</td>
# <td align="left">白</td>
# <td align="left">あり</td>
# </tr>
# <tr>
# <td align="left">dark</td>
# <td align="left">暗</td>
# <td align="left">なし</td>
# </tr>
# <tr>
# <td align="left">white</td>
# <td align="left">白</td>
# <td align="left">なし</td>
# </tr>
# <tr>
# <td align="left">ticks</td>
# <td align="left">白</td>
# <td align="left">なし, 軸に刻み線あり</td>
# </tr>
# </tbody></table>

# %% [markdown]
# ## 折れ線グラフ
# sns.lineplot(x, y, data=dataframe)

# %% [markdown]
# <table class=""><thead><tr><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">引数</th><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">説明</th></tr></thead><tbody><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">x, y（省略可）</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">データフレームのカラム名</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">data</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">データフレーム</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">hue</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">カラムのカテゴリを異なる色で描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">style</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">カラムのカテゴリを異なる線種で描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">ci</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">信頼区間の幅（デフォルト=95）で半透明のエラーバンドを表示<br data-rich-text-line-break="true">表示しない場合はNone</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">ax</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">グラフを描画したい領域（axesオブジェト）</td></tr></tbody></table>

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x="timepoint", y="signal", data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint", y="signal", data=fmri, ci=None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint", y="signal", data=fmri, hue="region")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint", y="signal", data=fmri, hue="region", style="event")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ## 棒グラフ
# sns.barplot()

# %% [markdown]
# <table class=""><thead><tr><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">引数</th><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">説明</th></tr></thead><tbody><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">x, y（省略可）</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">データフレームのカラム名（xに数値型の変数、yにカテゴリ変数を指定した場合は横棒グラフを描画）</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">data</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">データフレーム</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">order</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">表示する並び（リストで指定）</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">hue</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">カラムのカテゴリを異なる色で描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">ci</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">信頼区間の幅（デフォルト=95）で半透明のエラーバンドを表示<br data-rich-text-line-break="true">表示しない場合はNone</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">ax</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">グラフを描画したい領域（axesオブジェクトでの指定）</td></tr></tbody></table>

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Y軸に数値データじゃない値を入れると横棒グラフとなる
sns.barplot(x="tip", y="day", data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.barplot(x="total_bill", y="sex", data=tips, order=["Male","Female"], ci=None)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %%
#hue
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## 散布図
# sns.scatterplot()
# ※x,yの数値データの指定は必須

# %% [markdown]
# <table class=""><thead><tr><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">引数</th><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">説明</th></tr></thead><tbody><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">x, y</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">データフレームのカラム名</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">data</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">データフレーム</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">hue</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">カラムのカテゴリを異なる色で描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">style</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">カラムのカテゴリを異なる線種で描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">size</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">カラムのカテゴリを異なるサイズで描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">alpha</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">透明度</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">ax</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">グラフを描画したい領域（axesオブジェクトでの指定）</td></tr></tbody></table>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris, hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris, style="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris, size="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris, hue="species", size="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## 散布図行列
# sns.pairplot()

# %% [markdown]
# <table class=""><thead><tr><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">引数</th><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">説明</th></tr></thead><tbody><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">data</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">データフレーム</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">hue</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">カラムのカテゴリを異なる色で描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">kind</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">描画するグラフの種類 ：scatter・reg</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">diag_kind</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" contenteditable="true" style="white-space: pre-wrap;">対角線上に描画するグラフの種類 ：hist・kde</td></tr></tbody></table>

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris, hue="species")

# %%
sns.pairplot(data=iris, hue="species", kind="reg")

# %%
sns.pairplot(data=iris, hue="species", diag_kind="hist")

# %% [markdown]
# ## 箱ひげ図
# sns.boxplot()

# %% [markdown]
# <table class=""><thead><tr><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">引数</th><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">説明</th></tr></thead><tbody><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">x, y（省略可）</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">描画対象のデータのカラム名</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">data</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">描画対象のデータフレーム</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">order</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">出力する順番（文字列のリストで指定）</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">hue</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">指定したカラムのカテゴリでデータを分割し、グラフを描画</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">ax</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">グラフを描画したい領域（axesオブジェクトでの指定）</td></tr></tbody></table>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="species", y="sepal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
plt.title("boxenplot")
sns.boxenplot(x="species", y="sepal_length", data=iris)
# Out:
# <AxesSubplot:title={'center':'boxenplot'}, xlabel='species', ylabel='sepal_length'>

# %%
plt.title("violinplot")
sns.violinplot(x="species", y="sepal_length", data=iris)
# Out:
# <AxesSubplot:title={'center':'violinplot'}, xlabel='species', ylabel='sepal_length'>

# %%
plt.title("swarmplot")
sns.swarmplot(x="species", y="sepal_length", data=iris)
# Out:
# <AxesSubplot:title={'center':'swarmplot'}, xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ## ヒストグラム
# sns.histplot()

# %%
sns.histplot(iris["sepal_width"])
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(iris["sepal_width"], bins=20)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(iris, x="sepal_width", hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(iris, x="sepal_width", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(iris, x="sepal_width", hue="species", kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %% [markdown]
# ## ヒートマップ
# sns.heatmap()

# %% [markdown]
# <table class=""><thead><tr><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">引数</th><th role="textbox" aria-multiline="true" aria-label="ヘッダーラベル" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">説明</th></tr></thead><tbody><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">x, y（省略可）</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">描画対象のデータのカラム名</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">data</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">データフレーム</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">bin</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">ビンの分割</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">annot</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">数値の表示</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">linewidths</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">各セルを分割する線の幅</td></tr><tr><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">ax</td><td role="textbox" aria-multiline="true" aria-label="" class="rich-text block-editor-rich-text__editable wp-block-table__cell-content" style="white-space: pre-wrap;" contenteditable="true">グラフを描画したい領域（axesオブジェクトでの指定）</td></tr></tbody></table>

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights.pivot("month", "year", "passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(flights, annot=True, fmt="d")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(flights, linewidths=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(iris.corr(), annot=True, linewidths=2)
# Out:
# <AxesSubplot:>
