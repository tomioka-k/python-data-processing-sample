# %%
from IPython.display import Image

# %%
Image(data='https://upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Cherry_blossoms_%282004%29.jpg/300px-Cherry_blossoms_%282004%29.jpg',
     retina=True)

# %%
from IPython.display import Video

# %%
Video('https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4')
# Out:
# <video src="https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Audio

# %%
Audio("http://www.w3schools.com/html/horse.ogg")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import HTML

# %%
HTML("<h1>Hello World</h1>")
# Out:
# <h1>Hello World</h1>

# %%
html = """<style>
.table1 {
  border: 1px solid gray;
}
.table1 th, .table1 td {
  border: 1px solid gray;
}
</style>
</head>
<body>
<table class="table1">
  <tr><th></th><th>列-A</th><th>列-B</th></tr>
  <tr><td>行-1</td><td>A-1</td><td>B-1</td></tr>
  <tr><td>行-2</td><td>A-2</td><td>B-2</td></tr>
  <tr><td>行-3</td><td>A-3</td><td>B-3</td></tr>
</table>"""
HTML(html)
# Out:
# <style>
# .table1 {
#   border: 1px solid gray;
# }
# .table1 th, .table1 td {
#   border: 1px solid gray;
# }
# </style>
# </head>
# <body>
# <table class="table1">
#   <tr><th></th><th>列-A</th><th>列-B</th></tr>
#   <tr><td>行-1</td><td>A-1</td><td>B-1</td></tr>
#   <tr><td>行-2</td><td>A-2</td><td>B-2</td></tr>
#   <tr><td>行-3</td><td>A-3</td><td>B-3</td></tr>
# </table>

# %%
HTML('https://www.google.com/')
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ja"><head><meta content="&#19990;&#30028;&#20013;&#12398;&#12354;&#12425;&#12422;&#12427;&#24773;&#22577;&#12434;&#26908;&#32034;&#12377;&#12427;&#12383;&#12417;&#12398;&#12484;&#12540;&#12523;&#12434;&#25552;&#20379;&#12375;&#12390;&#12356;&#12414;&#12377;&#12290;&#12373;&#12414;&#12374;&#12414;&#12394;&#26908;&#32034;&#27231;&#33021;&#12434;&#27963;&#29992;&#12375;&#12390;&#12289;&#12362;&#25506;&#12375;&#12398;&#24773;&#22577;&#12434;&#35211;&#12388;&#12369;&#12390;&#12367;&#12384;&#12373;&#12356;&#12290;" name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="35wroIB1iQHlhjhZ1Xa09Q">(function(){window.google={kEI:'u4lzYvStDM_N2roPk5ajsAc',kEXPI:'0,1302536,56873,6058,207,4804,925,1391,383,246,5,1354,4013,1237,11
# ...

# %%
from IPython.display import IFrame

# %%
src = 'https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3240.8280303808815!2d139.76493611555023!3d35.68123618019426!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x60188bfbd89f700b%3A0x277c49ba34ed38!2z5p2x5Lqs6aeF!5e0!3m2!1sja!2sjp!4v1609230982586!5m2!1sja!2sjp"'
IFrame(src, width='480', height='480')
# Out:
#         <iframe
#             width="480"
#             height="480"
#             src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3240.8280303808815!2d139.76493611555023!3d35.68123618019426!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x60188bfbd89f700b%3A0x277c49ba34ed38!2z5p2x5Lqs6aeF!5e0!3m2!1sja!2sjp!4v1609230982586!5m2!1sja!2sjp""
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
src = 'https://en.wikipedia.org/wiki/IFrame'
IFrame(src, width=500, height=500)
# Out:
#         <iframe
#             width="500"
#             height="500"
#             src="https://en.wikipedia.org/wiki/IFrame"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import YouTubeVideo

# %%
# URL = https://www.youtube.com/watch?v=I-m7_BbBKGs
YouTubeVideo('I-m7_BbBKGs', width=400, height=300)
